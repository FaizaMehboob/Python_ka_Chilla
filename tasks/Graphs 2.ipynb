# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median
a=sns.load_dataset("titanic")
a
sns.barplot(x="fare", y="class", hue="sex",data=a, estimator=median, saturation=1)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median
a=sns.load_dataset("iris")
a
sns.barplot(x="sepal_length", y="sepal_width", hue="species", data=a, estimator=median, saturation=1)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median
a=sns.load_dataset("titanic")
a
sns.barplot(x="class", y="fare",data=a, 
linewidth=8, facecolor=(0.1,0.3,1,0.2), 
errcolor=".4", edgecolor="0")
plt.show()

# %%
#faccolor

# %%
#Boxpllot
import seaborn 
from numpy import median
seaborn.set(style='whitegrid')
a=seaborn.load_dataset("titanic")

seaborn.boxplot(x="class", y="fare",data=a)
plt.show()

# %%
import seaborn
import matplotlib.pyplot as plt
seaborn.set(style='whitegrid')
tip=seaborn.load_dataset('tips')
tip

seaborn.boxplot(x='day', y='tip', data=tip, saturation=0.5)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import seaborn 
from numpy import median
import numpy
import pandas as pd

seaborn.set(style="whitegrid")

tip=sns.load_dataset('tips')
#tip.describe()

seaborn.boxplot(y=tip['total_bill'])
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %%
import seaborn as sns
from numpy import median
import numpy


sns.set(style="whitegrid")

tip=sns.load_dataset('tips')
#tip.describe()

seaborn.boxplot(x="tip",y="day",hue="smoker",data=tip, )
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
import seaborn as sns

sns.set(style="whitegrid")

tip=sns.load_dataset('tips')
#tip.describe()

seaborn.boxplot(x="day",y="tip", data=tip, color="violet")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
from numpy import median
import numpy


sns.set(style="whitegrid")

tip=sns.load_dataset('tips')
tip

sns.boxplot(x="tip",y="day", data=tip, hue="smoker")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
from numpy import median
import numpy


sns.set(style="whitegrid")

tip=sns.load_dataset('tips')
tip

sns.boxplot(x="tip",y="day", data=tip, hue="smoker", palette=["red", "blue", "green"])


# ax = sns.barplot(data=a, x='Scenario', y='Duration',
#                  hue='Program', ci=None, palette=["C0", "C1", "k"])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
from numpy import median
import numpy
import seaborn as sns 
import matplotlib.pyplot as plt

a = pd.read_csv("data2.csv")


sns.set(style="whitegrid")

# tip=sns.load_dataset('tips')
# tip

sns.boxplot(x="Gender",y="Location", data=a, hue="Age" , palette=["red", "blue", "green"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\QAIMKH~1\AppData\Local\Temp/ipykernel_3012/2738197374.py in <module>
#      13 # tip
#      14
# ---> 15 sns.boxplot(x="Gender",y="Location", data=a, hue="Age" , palette=["red", "blue", "green"])
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
# ...

# %%
import seaborn as sns
from numpy import median
import numpy
import pandas as pd

a=sns.load_dataset("titanic")
sns.boxplot(x="survived", y="age", data=a)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
a=sns.load_dataset("titanic")
sns.boxplot(x="survived", y="age", data=a,facet_wrap(['survived'],showmeans=True, meanprops={"marker": "+","markersize":"12", "markeredgecolor": "red"})
# plt.xlabel("how many alive", size=10),
# plt.ylabel("Age (years)"),
# plt.title("Box_PLOT")

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

a=sns.load_dataset("titanic")
g=sns.FacetGrid(a,row="sex", hue="alone")
g=(g.map(plt.scatter,"age","fare").add_legend())
sns.boxplot(x="survived", y="age", data=a)


plt.show()

# %%
#Lineplot
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as ps

a=sns.load_dataset("dots")
a.head()

# pelette-sns.color_palette('rocket_r')

# sns.replot(data=a,)

# %%
#Error
#Lineplot
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as ps

a=sns.load_dataset("titanic")

sns.set_theme(style="ticks")

p=sns.color_palette('rocket_r')

sns.relplot(
    data=a,
    x="time", y="firing_rate",
    hue="coherence",  size="choice", col="align",
    kind="line",size_order=["T1","T2"], pallete=p,
    height=5, aspects=.75, facet_kws=dict(sharex=False),
)

#plt.show()

# %%
import seaborn as sns
from numpy import median
import numpy


sns.set(style="whitegrid")
sns.set_theme(style="ticks", palette="pastel")


tips=sns.load_dataset('tips')

sns.boxplot(x="day",y="total_bill", hue="smoker", palette=["m", "g"],
            data=tips)
sns.despine(offset=10, trim=True)

# %%
import seaborn as sns
from numpy import median
import numpy


sns.set_theme(style="whitegrid")
#sns.set_theme(style="ticks", palette="pastel")


tips=sns.load_dataset('tips')

sns.violinplot(x="day",y="total_bill", hue="smoker", spilt=True,
               inners="quart", linewidth=1, palette={"Yes":"b","No": ".85"}, data=tips)
sns.despine(left=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt


data2 = pd.read_csv("data2.csv")
data2

sns.set_theme(style="whitegrid")

# diamonds=sns.load_dataset("diamonds")
# diamonds
# 
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking=["I1", "SI2","SI1","VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="Qualification_completed", y="Age",
                 hue="Location",size="code_years",
                 palette="ch:r=-.2,d=3_r",
                 hue_order=clarity_ranking,
                 data=data2,ax=ax)

# %%
import seaborn as sns
sns.set_theme(style="ticks")

df=sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %%
import seaborn as sns 
sns.set_theme(style="whitegrid")

a=sns.load_dataset("dots")
sns.boxplot(x="choice", y="coherence",
           color="b",
           scale="linear",data=a)
