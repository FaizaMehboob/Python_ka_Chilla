# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

chilla = pd.read_csv("data_viz.csv")
sns.set_theme(style="ticks", color_codes=True)
g=sns.FacetGrid(chilla,row="Age", hue="Gender")
g=(g.map(plt.scatter,"Age","Gender").add_legend())

g.set_titles()

plt.show()

# %%
# import library
import pandas as pd

#import data from file
dataa = pd.read_csv("data_viz.csv")
#print(dataa)

sns.set_theme(style="ticks", color_codes=True)
sns.countplot(x="Age", data=dataa)
plt.show()

# %%
# import library
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt


chilla = pd.read_csv("data_viz.csv")
sns.set_theme(style="ticks", color_codes=True)
titanic=sns.load_dataset("titanic")
p=sns.countplot(x="sex", data=titanic, hue="class")
p.set_title("Title giving to Graph")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Titani_Data
#from seaborn.utils import load_dataset
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
titanic=sns.load_dataset("titanic")
print(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
titanic=sns.load_dataset("titanic")
p1=sns.countplot(x='who', data=titanic, hue='alone')
p1.set_title("This is New Ttile")
plt.show()

# %%
#Sir coding
# Step-1 import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Step-2 set a theme
sns.set_theme(style="ticks", color_codes=True)

# Step-3 import data set you can also import your own data
kashti =  sns.load_dataset("titanic")
#print(kashti)

# # Step-4 plot basic graph with 1 variable (count)
p = sns.countplot(x= "sex", data=kashti)
plt.show()

# Step-5 plot basic graph with 2 variable (count plot)
p = sns.countplot(x= "sex", data=kashti, hue="class")
plt.show()

# Step-6 plot basic graph with 2 variable (count plot) wiith Titles
p = sns.countplot(x= "sex", data=kashti, hue="class")
p.set_title("Baba_aammar ka count plot for kashti")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dataa=sns.load_dataset("iris")
dataa
# sns.lineplot(x="sepal_length", y="sepal_width", data=dataa)

# # plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dataa=sns.load_dataset("iris")
dataa
sns.lineplot(x="sepal_length", y="sepal_width", data=dataa)
plt.title("Using Iris ")
plt.xlim(2)
plt.xlim(3)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dataa=sns.load_dataset("iris")
dataa
sns.lineplot(x="sepal_length", y="sepal_width", data=dataa)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dataa=sns.load_dataset("iris")
dataa
sns.lineplot(x="sepal_length", y="sepal_width", data=dataa)
sns.lineplot(data=dataa);
plt.title("darkgrid")
plt.show()

# %%
#Setting size
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

dataa= pd.read_csv("data_viz.csv")
sns.set_theme(style="ticks", color_codes=True)
sns.lineplot(x="Age", y="Location", data=dataa)
plt.figure(figsize=(8,10))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd

dataa=sns.load_dataset("iris")
dataa
sns.barplot(x="species", y="petal_length", data=dataa)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median

a=sns.load_dataset("titanic")
a

sns.barplot(x="sex", y="alone", hue="who", data=a, order=["female", "male"], color="red", ci=None, palette="dark")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median
a=sns.load_dataset("titanic")
a
sns.barplot(x="class", y="fare", hue="sex",data=a, estimator=median, saturation=0.5)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style=None, rc=None) 
# load dataset
phool = sns.load_dataset("iris")
phool

# draw a lineplot
sns.lineplot(x="sepal_length", y="sepal_width", data=phool)
plt.title("phoolon ka plot")
sns.set_style("whitegrid")
plt.show()
