# %%
2nd#Operators
(3+4)  #Addition
print(7-4)   #Subtraction
print(10/2) #Divisionwithfloatingpoints
print(3*3)   #Multiplication
print(15%2)#Reminder
print(10//2) #Division
# Out:
# 3
# 5.0
# 9
# 1
# 5

# %%
3#Strings
print("Faiza")
print('Faiza')
print(''' Faiza''')
# Out:
# Faiza
# Faiza
#  Faiza

# %%
# 4Comment 
#multiline comments

# %%
5#Variabales
2+3
a=5
print(a)
a=4
print(a)
(print(type(a)))

#string Variable
y="Hello string"
print(y)
fruitbasket="mangoes"
print(fruitbasket)
# Out:
# 5
# 4
# <class 'int'>
# Hello string
# mangoes

# %%
6#InputVariable
fruitbasket="What fruit you like"
print(fruitbasket)
# Out:
# What fruit you like

# %%
fruitbasket=input("What is your favourite fruit")
print(fruitbasket)
# Out:
# What is your favourite fruitaapple
# aapple

# %%
#Name=input("What is your name: ")
#print(Name)
greetings="Hello"

Name=input("What is your name: ")
age=input("What is your age")
print(greetings,Name,age, ",you are still young")
# Out:
# What is your name: faiza
# What is your age18
# Hello faiza 18 ,you are still young

# %%
7#Conditional_Logic
#equal to ==
#less than <
#greater than >
#not equal to !<
#less than or equal to <=
#greater than or equal to >=

print(4==4)
print(4!=4)
print(4<=5)
print(5>=8)
# Out:
# True
# False
# True
# False

# %%
#Application of logical operator 
# Hmmad_age=3
# age_school=5
# print(Hmmad_age==age_school)
Hmmad_age=3
age_school=5
print(Hmmad_age==age_school)
print(type(Hmmad_age))
# Out:
# False
# <class 'int'>

# %%
#9If_Else_Elif
x=15
y=2.3
z="Hello"
print(type(z))
print(type(y))
8#implicit type conversion
x=x*y
# Out:
# <class 'str'>
# <class 'float'>

# %%
age=input("What is your age")
#age=int(age)
#print(type(age))
#print(int(age))
print(age,type(int(age)))
# Out:
# What is your age7
# 7 <class 'int'>

# %%
name=input("What is your name?")
print(name, type(str(name)))
# Out:
# What is your name?67
# 67 <class 'int'>

# %%
##IF ELSE
Hmmad_age=3
age_school=7
if Hmmad_age==age_school:
  print("Hammad can join the school")
elif Hmmad_age < age_school:
  print("Hammad join Kindergarten")
else:
  print("cannot goto school or can join later")
# Out:
# Hammad join Kindergarten

# %%
#10 IF ELSE ELIF


1#wrintig a Function
def print_line():
  print("We are learning with Sir Ammar")
  print("We are learning with Sir Ammar")
  print("We are learning with Sir Ammar")

print_line()
# Out:
# We are learning with Sir Ammar
# We are learning with Sir Ammar
# We are learning with Sir Ammar

# %%
#2ndway
def dWay():
  text="We are learnig"
  print(text)
  print(text)
  print(text)
dWay()
# Out:
# We are learnig
# We are learnig
# We are learnig

# %%
#3rway
def tway(text):
  print(text)
  print(text)
  print(text)
tway("we are learing with Sir Ammar")
# Out:
# we are learing with Sir Ammar
# we are learing with Sir Ammar
# we are learing with Sir Ammar

# %%
#Function with if else elif
def school_cal(age, text):
  if age==5:
    print("Hammad can join the school")
  elif age>5:
    print("Hammad can join the school")
  else:
    print("Hammad is baby")
school_cal(2 , "Hammad")
# Out:
# Hammad is nbaby

# %%
def future_age(a):
  newage=a+20
  return newage
  print(newage)
futurePredicte_age=future_age(18)
print(futurePredicte_age)
# Out:
# 38

# %%
#11 Loop
#while Loop
x=0
while(x<=5):
  print(x)
  x=x+1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# for x in range(5, 10):
#   print(x)
#array

days=["Mon","Tue","Wed","Thur","fri"]
for d in days:
 # if (d=="Wed"):break
  if (d=="fri"): continue
  print(d)
# Out:
# Mon
# Tue
# Wed
# Thur

# %%
#12 Import Liabraries
import math
print("The value of PI is", math.pi)

import statistics
x=[150,250,350,450,550]
print(statistics.mean(x))
# Out:
# The value of PI is 3.141592653589793
# 350

# %%
#TRIUBLE_SHOOTING

#print("Here) syntaxEror

#print(25/0) #runTimeError

name=("Faiza")
#print("Hello name") #semantic error will not print name
print("Hello " + name)
# Out:
# Hello Faiza
