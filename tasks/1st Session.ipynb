# %%
#Indexing
a="samosa, pakora"
a
# Out:
# 'samosa, pakora'

# %%
a
# Out:
# 'samosa, pakora'

# %%
a[0]
# Out:
# 's'

# %%
a[1]
# Out:
# 'a'

# %%
a[3]
# Out:
# 'o'

# %%
#length of indecies
len(a)
# Out:
# 14

# %%
a[0:5]
# Out:
# 'samos'

# %%
a[0:15]
# Out:
# 'samosa, pakora'

# %%
a[6]

# %%
a[-3]
# Out:
# 'o'

# %%
a[-6:13]
# Out:
# 'pakor'

# %%
food="biryani"
food
# Out:
# 'Biryani'

# %% [markdown]
# String Methods

# %%
food
# Out:
# 'Biryani'

# %%
len(food)
# Out:
# 7

# %%
food.capitalize()
# Out:
# 'Biryani'

# %%
food.upper()
# Out:
# 'BIRYANI'

# %%
food.replace("b", "Sh")
# Out:
# 'Biryani'

# %% [markdown]
# converting a specific alphabbet in string

# %%
name="Faizaaaa"
name
# Out:
# 'Faizaaaa'

# %%
name.count("a")
# Out:
# 5

# %%
#finidng an index number in string

# %%
name="Faiza"
name
name.find("i")
# Out:
# 2

# %%
#How to split string

# %%
food = "I like: mango, grapes,oranges,dates"
food.split(",")
# Out:
# ['I like: mango', ' grapes', 'oranges', 'dates']

# %% [markdown]
# Basic Data Structures in Python
# # Tuple
# # list
# # Dictionaries
# # Set

# %%
#ordered collections of element
#inclsed in braces ()
#can store differnt types of elements
#Once elemnts are stored it cannot be changed

# %%
tupl=(1, "Python", 3, True)
tupl

#TYPE
#type(tupl)
# Out:
# (1, 'Python', 3, True)

# %% [markdown]
# ###INDEXING in Tuple

# %%
tupl[0:4]
# Out:
# (1, 'Python', 3, True)

# %%
len(tupl)
# Out:
# 4

# %%
tup2=(2,"Faiza", 3.5, False)
tup2
# Out:
# (2, 'Faiza', 3.5, False)

# %%
tupl+tup2
# Out:
# (1, 'Python', True, 2, 'Faiza', 3.5, False)

# %%
tupl*3+tup2
# Out:
# (1,
#  'Python',
#  True,
#  1,
#  'Python',
#  True,
#  1,
#  'Python',
#  True,
#  2,
#  'Faiza',
#  3.5,
#  False)

# %%
tup3=(20,30,40,45,65)
tup3
# Out:
# (20, 30, 40, 45, 65)

# %%
min(tup3)
# Out:
# 20

# %%
max(tup3)
# Out:
# 65

# %%
#Concatinate_Adding 2 or more tupls

# %%
tup3*3
# Out:
# (20, 30, 40, 45, 65, 20, 30, 40, 45, 65, 20, 30, 40, 45, 65)

# %% [markdown]
# ###LIST
# oreddered collection of element
# inclosed in []
# we can change elements

# %%
list1=[2, "Faiza", False] 
list
# Out:
# list

# %%
len(list1)
# Out:
# 3

# %%
list2=["Faiza",3, 5, "yes", False]
list2
# Out:
# ['Faiza', 3, 5, 'yes', False]

# %%
list1+list2
# Out:
# [2, 'Faiza', False, 'Faiza', 3, 5, 'yes', False]

# %%
list2*4
# Out:
# ['Faiza',
#  3,
#  5,
#  'yes',
#  False,
#  'Faiza',
#  3,
#  5,
#  'yes',
#  False,
#  'Faiza',
#  3,
#  5,
#  'yes',
#  False,
#  'Faiza',
#  3,
#  5,
#  'yes',
#  False]

# %%
list1.reverse()
list1
# Out:
# [2, 'Faiza', False]

# %%
list1.append("Hello")
list1
# Out:
# [2, 'Faiza', False, 4, 'Hiiii', 'Hello']

# %%
list1=["maths", 3, "Eng"]
list1.extend("B")
list1
# Out:
# ['maths', 3, 'Eng', 'B']

# %%
list1.insert(1, "me")
list1
# Out:
# ['maths', 'me', 3, 'Eng', 'me', 'B', 'me']

# %%
list=[2,5,3,6,8]
list.sort()
list
# Out:
# [2, 3, 5, 6, 8]

# %%
list.pop(2)
list
# Out:
# [2, 3, 8]

# %%
list.reverse()
list
# Out:
# [8]

# %%
list3=[20, 30, 56,76,78,89,90]
len(list3)
# Out:
# 7

# %%
list3.sort()
list3
# Out:
# [20, 30, 56, 76, 78, 89, 90]

# %%
list1+list2
# Out:
# [2, 'Faiza', False, 4, 'Hiiii', 'Hello', 'Faiza', 3, 5, 'yes', False]

# %%
list1 = [5,6,7,2,5,7,8,7,9]
print(list1.count(7))


list3 = ["Eclairs", "DairyMilk", "Eclairs", "kitkat", "Now", "Eclairs"]
print(list3.count("Eclarirs"))
# Out:
# 3
# 0

# %% [markdown]
# DICTIONERIES
# An ordered collection of elements
# {} use this
# can change value

# %%
#Food and their prices
food = {"samosa":30, "Raita":20, "Pakora":100, "Salad":50, "Chicken Rolls":30}
food
# Out:
# {'Chicken Rolls': 30, 'Pakora': 100, 'Raita': 20, 'Salad': 50, 'samosa': 30}

# %%
type(food)
# Out:
# dict

# %%
keys1 = food.keys()
keys1
# Out:
# dict_keys(['samosa', 'Raita', 'Pakora', 'Salad', 'Chicken Rolls'])

# %%
value1=food.values()
value1
# Out:
# dict_values([30, 20, 100, 50, 30])

# %%
food["Tikke"]=10
food
# Out:
# {'Chicken Rolls': 30,
#  'Pakora': 100,
#  'Raita': 20,
#  'Salad': 50,
#  'Tikke': 10,
#  'samosa': 30}

# %%
#Update the value
food["Tikki"]=15
food
# Out:
# {'Chicken Rolls': 30,
#  'Pakora': 100,
#  'Raita': 20,
#  'Salad': 50,
#  'Tikke': 10,
#  'Tikki': 15,
#  'samosa': 30}

# %%
food2={"Dates":50, "Mangoes": 200, " Chocoloates":100}
food2
# Out:
# {' Chocoloates': 100, 'Dates': 50, 'Mangoes': 200}

# %%
food.update(food2)
food
# Out:
# {' Chocoloates': 100,
#  'Chicken Rolls': 30,
#  'Dates': 50,
#  'Mangoes': 200,
#  'Pakora': 100,
#  'Raita': 20,
#  'Salad': 50,
#  'Tikke': 10,
#  'Tikki': 15,
#  'samosa': 30}

# %%
mobile = {"nokia" "samsubg", "oppo", "vivo", "Q"}
mobile.clear()
mobile
# Out:
# set()

# %%
mobile = {"nokia":10, "samsung":20 , "oppo":30, "vivo":40, "Q":50}
mobile.clear()
mobile
# Out:
# {}

# %%
mobile = {2,5,3,7,8,9,4,5}
a=mobile.copy()
a
# Out:
# {2, 3, 4, 5, 7, 8, 9}

# %%
mobile = {"nokia":10, "samsung":20 , "oppo":30, "vivo":40, "Q":50}
a=mobile.get("nokia")
a
# Out:
# 10

# %%
mobile = {"nokia":10, "samsung":20 , "oppo":30, "vivo":40, "Q":50}
a=mobile.items()
a
# Out:
# dict_items([('nokia', 10), ('samsung', 20), ('oppo', 30), ('vivo', 40), ('Q', 50)])

# %%
mobile = {"nokia":"one", "samsung":"two" , "oppo":"three", "vivo":"four", "Q":"five"}
a=mobile.setdefault("oppo", "Done")
a
# Out:
# 'three'

# %% [markdown]
# ###SETS
# unordered aand uninidexed
# curly brace{}
# no duplicates

# %%
s1={1, 2.2, 3, "Faiza","chocolates", "Hyderabad", True}
s1
# Out:
# {1, 2.2, 3, 'Faiza', 'Hyderabad', 'chocolates'}

# %%
s1.add(5)
s1
# Out:
# {1, 2.2, 3, 5, 'Faiza', 'Hyderabad', 'chocolates'}

# %%
s1={1, 2.2, 3, "Faiza","chocolates", "Hyderabad", True}
s2={1, 4, 3, "Faiza","cakes", "karcahi", True}
s1.difference(s2)
s1
# Out:
# {1, 2.2, 3, 'Faiza', 'Hyderabad', 'chocolates'}

# %%
s1={1, 2.2, 3, "Faiza","chocolates", "Hyderabad", True}
s1.remove("Hyderabad")
s1
# Out:
# {1, 2.2, 3, 'Faiza', 'chocolates'}

# %%
s2={1, 4, 3, "Faiza","cakes", "karcahi", True}
s2.remove(4)
s2
# Out:
# {1, 3, 'Faiza', 'cakes', 'karcahi'}

# %%
s1={1, 2, 3,4, 5}
s2={1, 4, 3, 5,7,8,9}
s1.intersection()
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s1={1, 2, 3,4, 5}
s2={1, 4, 3, 5,7,8,9}
s2.isdisjoint(s1)
s2
# Out:
# {1, 3, 4, 5, 7, 8, 9}

# %%
s1={1, 2, 3,4, 5}
s2={1, 4, 3, 5,7,8,9}
s3=s1.issubset(s2)
s3
# Out:
# False

# %%
s1={1, 2, 3,4, 5}
s2={1,2, 4, 3, 5,7,8,9}
s3=s2.symmetric_difference(s1)
s3
# Out:
# {7, 8, 9}

# %%
s1={1, 2, 3,4, 5}
s2={1, 4, 3, 5,7,8,9}
s3=s1.union(s2)
s3
# Out:
# {1, 2, 3, 4, 5, 7, 8, 9}

# %%
s1={1, 3, 5,7, 9}
s2={2, 4, 6, 8}
s2.update(s1)
s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
