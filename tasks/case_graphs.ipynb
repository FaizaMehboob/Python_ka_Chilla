# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


a=pd.read_csv('dataa.csv')

sns.boxplot(y='Value', data=a)
# Out:
# <AxesSubplot:ylabel='Value'>

# %%
sns.set_theme(style="darkgrid")

a=pd.read_csv('dataa.csv')

# Plot the responses for different events and regions
sns.lineplot(x="Year", y="Value",
             #hue="Item", style="event",
             data=a)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
sns.set_theme(style="darkgrid")

a=pd.read_csv('dataa.csv')

# Plot the responses for different events and regions
p=sns.lineplot(x="Year", y="Value",
             hue="Item", style="Area",
             data=a)
p.set_title("Food Balance")
# Out:
# Text(0.5, 1.0, 'Title giving to Graph')
