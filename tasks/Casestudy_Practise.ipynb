# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

a=pd.read_csv('dataa.csv')
a.head()
# Out:
#   Domain Code                                             Domain  Area Code  \
# 0        FBSH  Food Balances (-2013, old methodology and popu...        165
# 1        FBSH  Food Balances (-2013, old methodology and popu...        165
# 2        FBSH  Food Balances (-2013, old methodology and popu...        165
# 3        FBSH  Food Balances (-2013, old methodology and popu...        165
# 4        FBSH  Food Balances (-2013, old methodology and popu...        165
#
#        Area  Element Code     Element  Item Code        Item  Year Code  Year  \
# 0  Pakistan          5511  Production       2536  Sugar cane       1961  1961
# 1  Pakistan          5511  Production       2536  Sugar cane       1962  1962
# 2  Pakistan          5511  Production       2536  Sugar cane       1963  1963
# 3  Pakistan          5511  Production       2536  Sugar cane       1964  1964
# 4  Pakistan          5511  Production       2536  Sugar cane       1965  1965
#
# ...

# %%
new_a=a.drop(['Item','Year Code', 'Flag'], axis =1)
new_a.head()
# Out:
#   Domain Code                                             Domain  Area Code  \
# 0        FBSH  Food Balances (-2013, old methodology and popu...        165
# 1        FBSH  Food Balances (-2013, old methodology and popu...        165
# 2        FBSH  Food Balances (-2013, old methodology and popu...        165
# 3        FBSH  Food Balances (-2013, old methodology and popu...        165
# 4        FBSH  Food Balances (-2013, old methodology and popu...        165
#
#        Area  Element Code     Element  Item Code  Year         Unit  Value  \
# 0  Pakistan          5511  Production       2536  1961  1000 tonnes  11640
# 1  Pakistan          5511  Production       2536  1962  1000 tonnes  14357
# 2  Pakistan          5511  Production       2536  1963  1000 tonnes  18438
# 3  Pakistan          5511  Production       2536  1964  1000 tonnes  16139
# 4  Pakistan          5511  Production       2536  1965  1000 tonnes  18667
#
#     Flag Description
# 0  Standardized data
# ...

# %%
new_a.value_counts(["Value"])
# Out:
# Value
# 11640    1
# 35989    1
# 36976    1
# 38059    1
# 38865    1
# 41998    1
# 43606    1
# 43608    1
# 44427    1
# 44666    1
# 45230    1
# 46333    1
# 47168    1
# 47244    1
# 48042    1
# 49373    1
# 50045    1
# 52056    1
# 53104    1
# 53820    1
# 54742    1
# 55191    1
# 55309    1
# 58397    1
# 63750    1
# 36580    1
# 35494    1
# 14357    1
# 34287    1
# 16139    1
# 18438    1
# 18659    1
# 18667    1
# 19947    1
# 19963    1
# 21242    1
# 21971    1
# 21982    1
# 22309    1
# 23167    1
# 23911    1
# 25547    1
# 26370    1
# 27326    1
# 27498    1
# 27856    1
# 29523    1
# 30077    1
# 32140    1
# 32359    1
# 32534    1
# 33029    1
# 63920    1
# dtype: int64

# %%
new_a.mean()
# Out:
# C:\Users\Faiza\AppData\Local\Temp/ipykernel_7012/823899926.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_a.mean()
# Area Code         165.000000
# Element Code     5511.000000
# Item Code        2536.000000
# Year             1987.000000
# Value           36130.754717
# dtype: float64

# %%
a.mean()
# Out:
# C:\Users\Faiza\AppData\Local\Temp/ipykernel_7012/1798845826.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   a.mean()
# Area Code         165.000000
# Element Code     5511.000000
# Item Code        2536.000000
# Year Code        1987.000000
# Year             1987.000000
# Value           36130.754717
# dtype: float64

# %%
a.groupby(["Value"]).mean()
# Out:
#        Area Code  Element Code  Item Code  Year Code    Year
# Value
# 11640      165.0        5511.0     2536.0     1961.0  1961.0
# 14357      165.0        5511.0     2536.0     1962.0  1962.0
# 16139      165.0        5511.0     2536.0     1964.0  1964.0
# 18438      165.0        5511.0     2536.0     1963.0  1963.0
# 18659      165.0        5511.0     2536.0     1968.0  1968.0
# 18667      165.0        5511.0     2536.0     1965.0  1965.0
# 19947      165.0        5511.0     2536.0     1973.0  1973.0
# 19963      165.0        5511.0     2536.0     1972.0  1972.0
# 21242      165.0        5511.0     2536.0     1975.0  1975.0
# 21971      165.0        5511.0     2536.0     1969.0  1969.0
# 21982      165.0        5511.0     2536.0     1967.0  1967.0
# 22309      165.0        5511.0     2536.0     1966.0  1966.0
# 23167      165.0        5511.0     2536.0     1971.0  1971.0
# 23911      165.0        5511.0     2536.0     1974.0  1974.0
# ...
