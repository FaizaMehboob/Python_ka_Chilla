# %% [markdown]
# # Importing Liabraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Loading dataset

# %%
a = pd.read_csv("data1.csv")
a
# Out:
#     Domain Code                        Domain  Area Code      Area  \
# 0           QCL  Crops and livestock products        165  Pakistan
# 1           QCL  Crops and livestock products        165  Pakistan
# 2           QCL  Crops and livestock products        165  Pakistan
# 3           QCL  Crops and livestock products        165  Pakistan
# 4           QCL  Crops and livestock products        165  Pakistan
# ..          ...                           ...        ...       ...
# 175         QCL  Crops and livestock products        165  Pakistan
# 176         QCL  Crops and livestock products        165  Pakistan
# 177         QCL  Crops and livestock products        165  Pakistan
# 178         QCL  Crops and livestock products        165  Pakistan
# 179         QCL  Crops and livestock products        165  Pakistan
#
#      Element Code         Element  Item Code            Item  Year Code  Year  \
# 0            5312  Area harvested       1717  Cereals, Total       1961  1961
# ...

# %%
a.head(3)
# Out:
#   Domain Code                             Domain  Area Code      Area  \
# 0          FS  Suite of Food Security Indicators        165  Pakistan
# 1          FS  Suite of Food Security Indicators        165  Pakistan
# 2          FS  Suite of Food Security Indicators        165  Pakistan
#
#    Element Code Element  Item Code  \
# 0          6121   Value      21047
# 1          6121   Value      21048
# 2          6121   Value      21047
#
#                                                 Item  Year Code  Year Unit  \
# 0  Percentage of population using at least basic ...       2000  2000    %
# 1  Percentage of population using at least basic ...       2000  2000    %
# 2  Percentage of population using at least basic ...       2001  2001    %
#
#    Value Flag                Flag Description  Note
# 0   87.2    X  International reliable sources   NaN
# 1   29.6    X  International reliable sources   NaN
# 2   87.4    X  International reliable sources   NaN

# %%
a = pd.read_csv("data1.csv")
sns.set_theme(style="ticks", color_codes=True)
g=sns.FacetGrid(a,row="Element", hue="Year")
g=(g.map(plt.scatter,"Element","Year").add_legend())

g.set_titles()

plt.show()

# %%
a = pd.read_csv("data4.csv")

sns.set_theme(style="ticks", color_codes=True)
p=sns.countplot(x="Value", data=a)
p.set_title("New_one Graph")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a = pd.read_csv("data4.csv")
sns.pairplot(a, hue="Year")

p.set_title("New_one Graph")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a = pd.read_csv("data4.csv")

sns.lineplot(x="Year", y="Item Code", data=a)
plt.title("Graph")
#plt.xlim(2)
#plt.xlim(3)
plt.show()

# %%
a = pd.read_csv("data4.csv")
sns.lineplot(x="Year", y="Element Code", data=a)
sns.lineplot(data=a)
plt.title("darkgrid")
plt.show()

# %%
a = pd.read_csv("data4.csv")
sns.set(style='whitegrid')

sns.boxplot(x="Area", y="Value",data=a)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Value'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

a = pd.read_csv("data4.csv")
fig=px.scatter(a, x="Domain", y="Year", color="Item", marginal_y="violin", trendline="ols", template="simple_white")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5580/4092564587.py in <module>
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 import plotly.express as px
#       4
#       5 a = pd.read_csv("data4.csv")
#
# ModuleNotFoundError: No module named 'plotly'
