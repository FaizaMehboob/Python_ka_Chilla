# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Salary_Data.csv")

# %%
X = data.iloc[: , :-1]
y = data.iloc[: ,-1:]

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans 

df = DataFrame(data,columns=['YearsExperience','Salary'])

  
kmeans = KMeans(n_clusters=3).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)

plt.scatter(df['YearsExperience'], df['Salary'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()
# Out:
# [[6.50000000e+00 9.16173333e+04]
#  [3.21176471e+00 5.45702353e+04]
#  [9.40000000e+00 1.14670286e+05]]

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


df = DataFrame(data,columns=['YearsExperience','Salary'])
  
kmeans = KMeans(n_clusters=5,random_state= 0).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)

plt.scatter(df['YearsExperience'], df['Salary'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()
# Out:
# [[7.36000000e+00 9.81670000e+04]
#  [3.87500000e+00 6.00832500e+04]
#  [9.46666667e+00 1.16185000e+05]
#  [1.62000000e+00 4.13390000e+04]
#  [5.60000000e+00 8.22255000e+04]]
